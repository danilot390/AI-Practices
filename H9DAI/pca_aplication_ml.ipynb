# %% [markdown]
# # PRACTICAL APPLICATIONS - IMPLEMENTATION

# %% [markdown]
# # 1. Reducing Overfitting in Machine Learning Models
# __Objetive:__ Train models with reduced features using PCA to minimize overfitting.

# %%
from sklearn.decomposition import PCA 
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# Load dataset
data = load_iris()
X, y = data.data, data.target

# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Train and evaluate using cross-validation
model = RandomForestClassifier(random_state=42)
scores = cross_val_score(model, X_pca, y, cv=5)

print('Cross-validation scores with PCA: ', scores)
print('Average score: ', scores.mean())
# Out:
# Cross-validation scores with PCA:  [0.96666667 0.9        0.93333333 0.93333333 0.93333333]
# Average score:  0.9333333333333333

# %% [markdown]
# # 2. Speeding Up Computations
# __Objective:__ Use PCA to reduce dimensionality and speed up model training.

# %%
from sklearn.linear_model import LogisticRegression
import time

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

#  Measure training time without PCA
model = LogisticRegression()
start = time.time()
model.fit(X, y)
end = time.time()
print(f'Training time without PCA: {end-start:.4f} seconds.')

# Measure training time with PCA
start = time.time()
model.fit(X_pca, y)
end = time.time()
print(f'Training time with PCA: {end-start:.4f} seconds.')
# Out:
# Training time without PCA: 0.0145 seconds.
# Training time with PCA: 0.0013 seconds.
# /Users/daniloangeltitorodriguez/Documents/ML/Platzi/.env/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # 3. Data Visualization
# __Objective:__ Visualize high-dimensional datasets using PCA and t-SNE.

# %%
import matplotlib.pyplot as plt 
from sklearn.manifold import TSNE

# Visulize with PCA
X_pca = PCA(n_components=2).fit_transform(X)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.title('PCA Visualization')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Class')
plt.show()

# Visualize with t-SNE
X_tsne = TSNE(n_components=2, random_state=42).fit_transform(X)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.title('t-SNE Visualization')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.colorbar(label='Class')
plt.show()
