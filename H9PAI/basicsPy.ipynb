# %%
import numpy as np

array = np.array([1,2,3])
print(array * 2)
# Out:
# [2 4 6]

# %%
import pandas as pd

data = {'Name':['Alice', 'Bob'], 'Age':[25,30]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 4, 6]

plt.plot(x, y)
plt.title('Simple plot')
plt.show()

# %%
terms = ['Structures', 'Regression', 'Algorithms', 'Predictions']

for topic in terms:
    print(topic.upper())
# Out:
# STRUCTURES
# REGRESSION
# ALGORITHMS
# PREDICTIONS

# %%
string = 'Hello cabrones, live is beautiful.'

characters={}

for char in string:
    if char in characters:
        characters[char]+=1
    else:
        characters[char]=1

print(characters)
# Out:
# {'H': 1, 'e': 4, 'l': 4, 'o': 2, ' ': 4, 'c': 1, 'a': 2, 'b': 2, 'r': 1, 'n': 1, 's': 2, ',': 1, 'i': 3, 'v': 1, 'u': 2, 't': 1, 'f': 1, '.': 1}
